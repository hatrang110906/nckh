# %% [markdown]
# <a href="https://colab.research.google.com/github/hatrang110906/nckh/blob/main/%C4%91%E1%BB%A9a_con_%C4%91%E1%BA%A7u_l%C3%B2ng.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="LgwPkCOdJJvgwYS6G6On")
project = rf.workspace("nckh-ht").project("htwun-5jn46")
version = project.version(2)
dataset = version.download("yolov12")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 9.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 8.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 20.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 90.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 141.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.12.0.88
#     Uninstalling opencv-python-headless-4.12.0.88:
#       Successfully uninstalled opencv-python-headless-4.12.0.88
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to htwun-2 in yolov12:: 100%|██████████| 6178/6178 [00:00<00:00, 6790.67it/s]

# %%
# !git clone https://github.com/ultralytics/ultralytics
# %cd ultralytics
# !pip install -e .
# Out:
# Cloning into 'ultralytics'...
# remote: Enumerating objects: 72403, done.
# remote: Counting objects: 100% (152/152), done.
# remote: Compressing objects: 100% (105/105), done.
# remote: Total 72403 (delta 77), reused 58 (delta 47), pack-reused 72251 (from 2)
# Receiving objects: 100% (72403/72403), 39.00 MiB | 14.81 MiB/s, done.
# Resolving deltas: 100% (54311/54311), done.
# /content/ultralytics
# Obtaining file:///content/ultralytics
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for ultralytics (pyproject.toml) ... done
#   Created wheel for ultralytics: filename=ultralytics-8.3.226-0.editable-py3-none-any.whl size=23155 sha256=77d39a15b1a0d87b03c66b508e68eb90f808c4c2924d97a4604db5926f3875c4
# ...

# %%
from ultralytics import YOLO
model=YOLO("yolo12n.pt")
model.train(
    data="/content/htwun-2/data.yaml",
    epochs=20,
    imgsz=640,
    batch=16,
)
# Out:
# Ultralytics 8.3.226 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from IPython.display import Image, Video, display

# %%
model=YOLO('/content/ultralytics/runs/detect/train3/weights/best.pt')
results=model.predict(source="/content/tét.jpg",save=True)
# Out:
# image 1/1 /content/tét.jpg: 480x640 1 black smoke, 7 humans, 55.1ms
# Speed: 2.8ms preprocess, 55.1ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to /content/ultralytics/runs/detect/predict

# %%
display(Image(filename='/content/ultralytics/runs/detect/predict/tét.jpg'))

# %%
results=model.predict(source="/content/sos.mp4",save=True)
# Out:
# WARNING ⚠️
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/409) /content/sos.mp4: 640x384 1 black smoke, 1 fire, 13.5ms
# video 1/1 (frame 2/409) /content/sos.mp4: 640x384 1 black smoke, 1 fire, 12.9ms
# video 1/1 (frame 3/409) /content/sos.mp4: 640x384 1 black smoke, 1 fire, 14.8ms
# video 1/1 (frame 4/409) /content/sos.mp4: 640x384 1 black smoke, 1 fire, 14.0ms
# video 1/1 (frame 5/409) /content/sos.mp4: 640x384 1 black smoke, 1 fire, 13.6ms
# ...

# %%
display(Video('/content/ultralytics/runs/detect/predict/sos.avi'))
# Out:
# <video src="/content/ultralytics/runs/detect/predict/sos.avi" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
results=model.predict(source="/content/ht.mp4",save=True)
# Out:
# WARNING ⚠️
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/569) /content/ht.mp4: 640x320 1 fire, 1 human, 2 smokes, 56.7ms
# video 1/1 (frame 2/569) /content/ht.mp4: 640x320 1 fire, 1 human, 1 smoke, 13.2ms
# video 1/1 (frame 3/569) /content/ht.mp4: 640x320 1 fire, 1 human, 1 smoke, 13.8ms
# video 1/1 (frame 4/569) /content/ht.mp4: 640x320 1 fire, 13.5ms
# video 1/1 (frame 5/569) /content/ht.mp4: 640x320 1 fire, 13.1ms
# ...

# %%
display(Video("/content/ultralytics/runs/detect/predict/ht.avi"))
# Out:
# <video src="/content/ultralytics/runs/detect/predict/ht.avi" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
results=model.predict(source="/content/ultr.mp4",save=True)
# Out:
# WARNING ⚠️
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/692) /content/ultr.mp4: 640x384 1 fire, 2 humans, 16.5ms
# video 1/1 (frame 2/692) /content/ultr.mp4: 640x384 1 fire, 2 humans, 13.5ms
# video 1/1 (frame 3/692) /content/ultr.mp4: 640x384 1 fire, 2 humans, 15.7ms
# video 1/1 (frame 4/692) /content/ultr.mp4: 640x384 1 fire, 2 humans, 13.0ms
# video 1/1 (frame 5/692) /content/ultr.mp4: 640x384 1 fire, 2 humans, 17.0ms
# ...

# %%
display(Video("/content/ultralytics/runs/detect/predict/ultr.avi"))
# Out:
# <video src="/content/ultralytics/runs/detect/predict/ultr.avi" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>
